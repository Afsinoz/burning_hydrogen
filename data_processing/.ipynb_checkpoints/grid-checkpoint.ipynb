# %%
from create_df import nc_to_dfs
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
files = ['AQUA_MODIS.20240101.L3m.DAY.CHL.chlor_a.4km.nc',
         'AQUA_MODIS.20240102.L3m.DAY.CHL.chlor_a.4km.nc',
         'AQUA_MODIS.20240103.L3m.DAY.CHL.chlor_a.4km.nc',
         'AQUA_MODIS.20240104.L3m.DAY.CHL.chlor_a.4km.nc',
         'AQUA_MODIS.20240105.L3m.DAY.CHL.chlor_a.4km.nc']

# %%
chlor_a, lon, lat, lon_1_dim, lat_1_dim = nc_to_dfs(files)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[111], line 1
# ----> 1 chlor_a, lon, lat, lon_1_dim, lat_1_dim = nc_to_dfs(files)
#
# ValueError: not enough values to unpack (expected 5, got 3)

# %%
lat
# Out:
# array([[-179.97917, -179.97917, -179.97917, ..., -179.97917, -179.97917,
#         -179.97917],
#        [-179.9375 , -179.9375 , -179.9375 , ..., -179.9375 , -179.9375 ,
#         -179.9375 ],
#        [-179.89583, -179.89583, -179.89583, ..., -179.89583, -179.89583,
#         -179.89583],
#        ...,
#        [ 179.89584,  179.89584,  179.89584, ...,  179.89584,  179.89584,
#          179.89584],
#        [ 179.93752,  179.93752,  179.93752, ...,  179.93752,  179.93752,
#          179.93752],
#        [ 179.97917,  179.97917,  179.97917, ...,  179.97917,  179.97917,
#          179.97917]], dtype=float32)

# %%
lon
# Out:
# array([[ 89.979164,  89.9375  ,  89.895836, ..., -89.895836, -89.93751 ,
#         -89.97917 ],
#        [ 89.979164,  89.9375  ,  89.895836, ..., -89.895836, -89.93751 ,
#         -89.97917 ],
#        [ 89.979164,  89.9375  ,  89.895836, ..., -89.895836, -89.93751 ,
#         -89.97917 ],
#        ...,
#        [ 89.979164,  89.9375  ,  89.895836, ..., -89.895836, -89.93751 ,
#         -89.97917 ],
#        [ 89.979164,  89.9375  ,  89.895836, ..., -89.895836, -89.93751 ,
#         -89.97917 ],
#        [ 89.979164,  89.9375  ,  89.895836, ..., -89.895836, -89.93751 ,
#         -89.97917 ]], dtype=float32)

# %%
plt.imshow(chlor_a[0])

# %%
plt.imshow(chlor_a[1])

# %%
plt.imshow(chlor_a[2])

# %%
plt.imshow(np.mean(chlor_a, axis=0))

# %%
lat_deg = 0.5

# %%
lon_deg = 0.5

# %%
lat
# Out:
# array([[-179.97917, -179.97917, -179.97917, ..., -179.97917, -179.97917,
#         -179.97917],
#        [-179.9375 , -179.9375 , -179.9375 , ..., -179.9375 , -179.9375 ,
#         -179.9375 ],
#        [-179.89583, -179.89583, -179.89583, ..., -179.89583, -179.89583,
#         -179.89583],
#        ...,
#        [ 179.89584,  179.89584,  179.89584, ...,  179.89584,  179.89584,
#          179.89584],
#        [ 179.93752,  179.93752,  179.93752, ...,  179.93752,  179.93752,
#          179.93752],
#        [ 179.97917,  179.97917,  179.97917, ...,  179.97917,  179.97917,
#          179.97917]], dtype=float32)

# %%
vals = (90 > lat) * (89.5 < lat) * (-180 < lon) * (-179.5 > lon)

# %%
vals
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
vals.shape
# Out:
# (8640, 4320)

# %%
chlor_a.shape
# Out:
# (5, 4320, 8640)

# %%
lon.shape
# Out:
# (8640, 4320)
